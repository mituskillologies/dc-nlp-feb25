# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# %%
pos_tag(['bigger'])
# Out:
# [('bigger', 'JJR')]

# %%
text = "India, officially the Republic of India,[j][21] is a country in South Asia. It is the seventh-largest country by area; the most populous country from June 2023 onwards;[22][23] and since its independence in 1947, the world's most populous democracy.[24][25][26] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia."

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/mitu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/mitu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
text
# Out:
# "India, officially the Republic of India,[j][21] is a country in South Asia. It is the seventh-largest country by area; the most populous country from June 2023 onwards;[22][23] and since its independence in 1947, the world's most populous democracy.[24][25][26] Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia."

# %%
tags = pos_tag(word_tokenize(text))

# %%
tags
# Out:
# [('India', 'NNP'),
#  (',', ','),
#  ('officially', 'RB'),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('[', 'NNP'),
#  ('j', 'NN'),
#  (']', 'NNP'),
#  ('[', 'VBZ'),
#  ('21', 'CD'),
#  (']', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('South', 'NNP'),
#  ('Asia', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('seventh-largest', 'JJ'),
#  ('country', 'NN'),
#  ('by', 'IN'),
#  ('area', 'NN'),
#  (';', ':'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('country', 'NN'),
#  ('from', 'IN'),
#  ('June', 'NNP'),
#  ('2023', 'CD'),
#  ('onwards', 'NNS'),
#  (';', ':'),
#  ('[', 'CC'),
#  ('22', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('23', 'CD'),
#  (']', 'NN'),
#  ('and', 'CC'),
#  ('since', 'IN'),
#  ('its', 'PRP$'),
#  ('independence', 'NN'),
#  ('in', 'IN'),
#  ('1947', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('world', 'NN'),
# ...

# %%
# remove punctuations
clean_text = [word for word in word_tokenize(text) if word.isalpha() or word.isdigit()]

# %%
clean_text
# Out:
# ['India',
#  'officially',
#  'the',
#  'Republic',
#  'of',
#  'India',
#  'j',
#  '21',
#  'is',
#  'a',
#  'country',
#  'in',
#  'South',
#  'Asia',
#  'It',
#  'is',
#  'the',
#  'country',
#  'by',
#  'area',
#  'the',
#  'most',
#  'populous',
#  'country',
#  'from',
#  'June',
#  '2023',
#  'onwards',
#  '22',
#  '23',
#  'and',
#  'since',
#  'its',
#  'independence',
#  'in',
#  '1947',
#  'the',
#  'world',
#  'most',
#  'populous',
#  'democracy',
#  '24',
#  '25',
#  '26',
#  'Bounded',
#  'by',
#  'the',
#  'Indian',
#  'Ocean',
#  'on',
#  'the',
#  'south',
#  'the',
#  'Arabian',
#  'Sea',
#  'on',
#  'the',
#  'southwest',
#  'and',
#  'the',
#  'Bay',
#  'of',
#  'Bengal',
#  'on',
#  'the',
#  'southeast',
#  'it',
#  'shares',
#  'land',
#  'borders',
#  'with',
#  'Pakistan',
#  'to',
#  'the',
#  'west',
#  'k',
#  'China',
#  'Nepal',
#  'and',
#  'Bhutan',
#  'to',
#  'the',
#  'north',
#  'and',
#  'Bangladesh',
#  'and',
#  'Myanmar',
#  'to',
#  'the',
# ...

# %%
pos_tag(clean_text)
# Out:
# [('India', 'NNP'),
#  ('officially', 'RB'),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('j', 'NN'),
#  ('21', 'CD'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('South', 'NNP'),
#  ('Asia', 'NNP'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('by', 'IN'),
#  ('area', 'NN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('country', 'NN'),
#  ('from', 'IN'),
#  ('June', 'NNP'),
#  ('2023', 'CD'),
#  ('onwards', 'NNS'),
#  ('22', 'CD'),
#  ('23', 'CD'),
#  ('and', 'CC'),
#  ('since', 'IN'),
#  ('its', 'PRP$'),
#  ('independence', 'NN'),
#  ('in', 'IN'),
#  ('1947', 'CD'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('democracy', 'NN'),
#  ('24', 'CD'),
#  ('25', 'CD'),
#  ('26', 'CD'),
#  ('Bounded', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('Ocean', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
# ...

# %%
for tags in pos_tag(clean_text):
    print(tags[0],'-->',tags[1])
# Out:
# India --> NNP
# officially --> RB
# the --> DT
# Republic --> NNP
# of --> IN
# India --> NNP
# j --> NN
# 21 --> CD
# is --> VBZ
# a --> DT
# country --> NN
# in --> IN
# South --> NNP
# Asia --> NNP
# It --> PRP
# is --> VBZ
# the --> DT
# country --> NN
# by --> IN
# area --> NN
# the --> DT
# most --> RBS
# populous --> JJ
# country --> NN
# from --> IN
# June --> NNP
# 2023 --> CD
# onwards --> NNS
# 22 --> CD
# 23 --> CD
# and --> CC
# since --> IN
# its --> PRP$
# independence --> NN
# in --> IN
# 1947 --> CD
# the --> DT
# world --> NN
# most --> RBS
# populous --> JJ
# democracy --> NN
# 24 --> CD
# 25 --> CD
# 26 --> CD
# Bounded --> VBN
# by --> IN
# the --> DT
# Indian --> JJ
# Ocean --> NNP
# on --> IN
# the --> DT
# south --> JJ
# the --> DT
# Arabian --> JJ
# Sea --> NNP
# on --> IN
# the --> DT
# southwest --> NN
# and --> CC
# the --> DT
# Bay --> NNP
# of --> IN
# Bengal --> NNP
# on --> IN
# the --> DT
# southeast --> NN
# it --> PRP
# shares --> NNS
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(pos_tag(clean_text), columns=['Word','POS'])
# Out:
#            Word  POS
# 0         India  NNP
# 1    officially   RB
# 2           the   DT
# 3      Republic  NNP
# 4            of   IN
# ..          ...  ...
# 111        with   IN
# 112    Thailand  NNP
# 113     Myanmar  NNP
# 114         and   CC
# 115   Indonesia  NNP
#
# [116 rows x 2 columns]

# %%
tags
# Out:
# ('Indonesia', 'NNP')

# %%
tags = pos_tag(clean_text)

# %%
tags
# Out:
# [('India', 'NNP'),
#  ('officially', 'RB'),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('j', 'NN'),
#  ('21', 'CD'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('South', 'NNP'),
#  ('Asia', 'NNP'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('by', 'IN'),
#  ('area', 'NN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('country', 'NN'),
#  ('from', 'IN'),
#  ('June', 'NNP'),
#  ('2023', 'CD'),
#  ('onwards', 'NNS'),
#  ('22', 'CD'),
#  ('23', 'CD'),
#  ('and', 'CC'),
#  ('since', 'IN'),
#  ('its', 'PRP$'),
#  ('independence', 'NN'),
#  ('in', 'IN'),
#  ('1947', 'CD'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('democracy', 'NN'),
#  ('24', 'CD'),
#  ('25', 'CD'),
#  ('26', 'CD'),
#  ('Bounded', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('Ocean', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
# ...

# %%
for tag in tags:
    if tag[1].startswith('N'):
        print(tag[0])
# Out:
# India
# Republic
# India
# j
# country
# South
# Asia
# country
# area
# country
# June
# onwards
# independence
# world
# democracy
# Ocean
# Sea
# southwest
# Bay
# Bengal
# southeast
# shares
# borders
# Pakistan
# west
# k
# China
# Nepal
# Bhutan
# north
# Bangladesh
# Myanmar
# east
# Ocean
# India
# Sri
# Lanka
# Maldives
# Andaman
# Nicobar
# Islands
# share
# maritime
# border
# Thailand
# Myanmar
# Indonesia

# %%
# Print only root form of the verbs present in the text

# %%
text = """Pune (/ˈpuːnə/ POO-nə; Marathi: [ˈpuɳe] ⓘ, ISO: Puṇē), previously spelled in English as Poona (the official name until 1978),[14][15] is a city in the state of Maharashtra in the Deccan plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. According to the 2011 Census of India, Pune has 7.2 million residents in the metropolitan region, making it the seventh-most populous metropolitan area in India.[16] The city of Pune is part of Pune Metropolitan Region.[17] Pune is one of the largest IT hubs in India.[18][19] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions.[20][21][22] It has been ranked "the most liveable city in India" several times."""

# %%
text
# Out:
# 'Pune (/ˈpuːnə/ POO-nə; Marathi: [ˈpuɳe] ⓘ, ISO: Puṇē), previously spelled in English as Poona (the official name until 1978),[14][15] is a city in the state of Maharashtra in the Deccan plateau in Western India. It is the administrative headquarters of the Pune district, and of Pune division. According to the 2011 Census of India, Pune has 7.2 million residents in the metropolitan region, making it the seventh-most populous metropolitan area in India.[16] The city of Pune is part of Pune Metropolitan Region.[17] Pune is one of the largest IT hubs in India.[18][19] It is also one of the most important automobile and manufacturing hubs of India. Pune is often referred to as the "Oxford of the East" because of its educational institutions.[20][21][22] It has been ranked "the most liveable city in India" several times.'

# %%
tags = pos_tag(word_tokenize(text))
verbs = []

for tag in tags:
    if tag[1].startswith('V') and tag[0].isalpha():
        verbs.append(tag[0])

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
for verb in verbs:
    print(wnl.lemmatize(verb.lower(), pos='v'))
# Out:
# spell
# be
# be
# accord
# have
# make
# be
# be
# be
# be
# refer
# have
# be
# rank
